# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scripts import *

# %%
data = aggregate_data()

# %%
data.head()
# Out:
#    Observation_id         Satellite                       Station Status  \
# 0         4874112  5580  - PROSPERO             1372 - HHSstation   Good
# 1         3712559  5580  - PROSPERO             1775 - Vi3w Roy4l   Good
# 2         5141223  14781  - UOSAT 2  2334 - M7CBR - VHF Turnstile    Bad
# 3         5141223  14781  - UOSAT 2  2334 - M7CBR - VHF Turnstile    Bad
# 4         5104170  14781  - UOSAT 2      1682 - N5ZKK-VHF-Helical   Good
#
#    Status_Message            Transmitter      Frequency              Mode  \
# 0             100  Mode V PCM 2048 bit/s  137,560,000Hz   ['FSK', '2048']
# 1             100  Mode V PCM 2048 bit/s  137,560,000Hz   ['FSK', '2048']
# 2            -100           1k2 AFSK TLM  145,825,000Hz  ['AFSK', '1200']
# 3            -100           1k2 AFSK TLM  145,825,000Hz  ['AFSK', '1200']
# 4             100           1k2 AFSK TLM  145,825,000Hz  ['AFSK', '1200']
#
#                                             Metadata  \
# 0  {"radio": {"name": "gr-satnogs", "version": "2...
# 1  {"radio": {"name": "gr-satnogs", "version": "v...
# 2  {"radio": {"name": "gr-satnogs", "version": "v...
# 3  {"radio": {"name": "gr-satnogs", "version": "v...
# 4  {"radio": {"name": "gr-satnogs", "version": "2...
#
#                                            Downloads  ... decayed    launched  \
# 0  {'audio': 'https://archive.org/download/satnog...  ...     NaN  1971-10-28
# 1  {'audio': 'https://archive.org/download/satnog...  ...     NaN  1971-10-28
# 2  {'audio': 'https://archive.org/download/satnog...  ...     NaN  1984-03-01
# 3  {'audio': 'https://archive.org/download/satnog...  ...     NaN  1984-03-01
# 4  {'audio': 'https://archive.org/download/satnog...  ...     NaN  1984-03-01
#
#    deployed  website operator  countries telemetries  \
# 0       NaN      NaN     None         UK          []
# 1       NaN      NaN     None         UK          []
# 2       NaN      NaN     None         UK          []
# 3       NaN      NaN     None         UK          []
# 4       NaN      NaN     None         UK          []
#
#                        updated                                 citation  \
# 0  2021-07-21T10:11:41.970160Z  CITATION NEEDED - https://xkcd.com/285/
# 1  2021-07-21T10:11:41.970160Z  CITATION NEEDED - https://xkcd.com/285/
# 2  2021-07-21T10:11:41.977018Z  CITATION NEEDED - https://xkcd.com/285/
# 3  2021-07-21T10:11:41.977018Z  CITATION NEEDED - https://xkcd.com/285/
# 4  2021-07-21T10:11:41.977018Z  CITATION NEEDED - https://xkcd.com/285/
#
#   associated_satellites_y
# 0                      []
# 1                      []
# 2                      []
# 3                      []
# 4                      []
#
# [5 rows x 39 columns]

# %%
data['Mode'].value_counts()
# Out:
# ['FSK', '9600']                   4848
# ['AFSK', '1200']                  3768
# ['GMSK', '9600']                  2708
# ['GFSK', '9600']                  1753
# ['BPSK', '1200']                  1553
# ['BPSK', '9600']                  1544
# ['GMSK', '4800']                  1445
# ['DUV', '200']                     962
# ['FSK AX.25 G3RUH', '9600']        953
# ['BPSK PMT-A3', '800']             839
# ['FSK AX.100 Mode 5', '9600']      786
# ['MSK AX.100 Mode 5', '9600']      635
# ['MSK AX.100 Mode 5', '4800']      480
# ['AFSK', '4800']                   467
# ['GFSK', '19200']                  435
# ['GMSK', '19200']                  358
# ['FSK AX.100 Mode 5', '4800']      326
# ['MSK AX.100 Mode 6', '9600']      311
# ['BPSK', '2400']                   288
# ['GMSK', '12500']                  275
# ['AFSK SALSAT', '1200']            270
# ['FSK AX.100 Mode 5', '1200']      254
# ['GFSK Rktr', '9600']              239
# ['AFSK', '']                       211
# ['BPSK', '']                       201
# ['GMSK', '2400']                   173
# ['AFSK S-Net', '1200']             125
# ['BPSK', '12500']                  112
# ['FSK', '19200']                   110
# ['GFSK', '9766']                    87
# ['BPSK', '4800']                    80
# ['FSK', '40000']                    66
# ['FSK', '1200']                     63
# ['BPSK', '128000']                  59
# ['GFSK', '38400']                   57
# ['GFSK', '0']                       56
# ['GFSK', '4800']                    50
# ['FSK', '']                         49
# ['FSK AX.100 Mode 5', '57600']      43
# ['GMSK', '1200']                    37
# ['FSK', '4800']                     25
# ['GMSK', '']                        19
# ['FSK', '14832']                    14
# ['FSK', '115200']                   13
# ['GFSK', '1200']                     8
# ['GMSK', '5000']                     3
# ['FSK', '2048']                      2
# ['PSK31', '']                        1
# ['GMSK', '14832']                    1
# ['BPSK', '400']                      1
# ['MSK', '4800']                      1
# Name: Mode, dtype: int64

# %%
data['SignalType'] = data['Mode'].apply(lambda x: x.split(',')[0][2:-1])
data['SignalRate'] = data['Mode'].apply(lambda x: x.split(',')[1][2:-2])
data['Ones'] = 1
data['Status_numeric'] = data['Status'].apply(lambda x: eval_obs_status(x))
data['SignalRate']
signal_modes = list(set(data['SignalType']))
signal_modes
# Out:
# ['DUV',
#  'AFSK',
#  'FSK AX.100 Mode 5',
#  'GFSK Rktr',
#  'GMSK',
#  'FSK AX.25 G3RUH',
#  'AFSK SALSAT',
#  'BPSK',
#  'MSK AX.100 Mode 5',
#  'PSK31',
#  'AFSK S-Net',
#  'BPSK PMT-A3',
#  'FSK',
#  'MSK',
#  'GFSK',
#  'MSK AX.100 Mode 6']

# %%
hypothesis_test_column(data, signal_modes, 'SignalType','../hypothesis_tests/signals/', alpha = 0.05)
# Out:
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
hypothesis_test_greater_counts(data, signal_modes, 'SignalType', alpha = 0.05)

# %%
data['SignalRate'].value_counts()
# Out:
# 9600      13777
# 1200       6078
# 4800       2874
# 200         962
# 19200       903
# 800         839
#             481
# 2400        461
# 12500       387
# 9766         87
# 40000        66
# 128000       59
# 38400        57
# 0            56
# 57600        43
# 14832        15
# 115200       13
# 5000          3
# 2048          2
# 400           1
# Name: SignalRate, dtype: int64

# %%
data['SignalRate'] = data['SignalRate'].apply(lambda x: x if len(x.strip()) > 0 else '0')
data['SignalRate'] = data['SignalRate'].astype(np.int)

# %%
with_rates = data[data['SignalRate'] > 0]
rate_index = list(set(with_rates['SignalRate'].values))

# %%
hypothesis_test_column(with_rates, rate_index, 'SignalRate','../hypothesis_tests/rates/', alpha = 0.05)
hypothesis_test_greater_counts(with_rates, rate_index, 'SignalRate', alpha = 0.05)
# Out:
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
# ...
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/ada/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: divide by zero encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False
# /home/ada/CodeProjects/SatNOGS2/Notebooks/scripts.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   equal_var = True if (((var1 / var2) <= 4) & ((var2 / var2) <=4) ) else False

# %%
rate_index
# Out:
# [2048,
#  2400,
#  9600,
#  800,
#  128000,
#  4800,
#  19200,
#  40000,
#  200,
#  9766,
#  57600,
#  5000,
#  400,
#  1200,
#  14832,
#  115200,
#  12500,
#  38400]
